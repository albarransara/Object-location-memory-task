# %%
#Compare the content of two .res files

def compare_res_files(file1, file2):
    with open(file1, 'r') as f1, open(file2, 'r') as f2:
        lines1 = f1.readlines()
        lines2 = f2.readlines()

    max_len = max(len(lines1), len(lines2))

    for i in range(max_len):
        line1 = lines1[i].rstrip("\n") if i < len(lines1) else "<NO LINE>"
        line2 = lines2[i].rstrip("\n") if i < len(lines2) else "<NO LINE>"

        if line1 != line2:
            print(f"Difference at line {i+1}:")
            print(f"  File 1: {line1}")
            print(f"  File 2: {line2}")
            print("-" * 40)


path_file1 = "../object location data/Alle data GOED/C01a.res"
path_file2 = "../object location data/Alle data GOED/controle01a.res"
compare_res_files(path_file1, path_file2)
# Out:
# Difference at line 295:
#   File 1: 1,.679,.674,"Calcul.ico  "
#   File 2: 1,.603,.239,"Calcul.ico  "
# ----------------------------------------
# Difference at line 298:
#   File 1: 2,.278,.346,"Camel.ico   "
#   File 2: 2,.679,.674,"Camel.ico   "
# ----------------------------------------
# Difference at line 301:
#   File 1: 3,.2318841,9.118541E-02,"Camera.ico  "
#   File 2: 3,.278,.346,"Camera.ico  "
# ----------------------------------------
# Difference at line 304:
#   File 1: 4,.684058,.9392097,"Candle.ico  "
#   File 2: 4,.2318841,9.118541E-02,"Candle.ico  "
# ----------------------------------------
# Difference at line 307:
#   File 1: 5,.885,.221,"Cap.ico     "
#   File 2: 5,.684058,.9392097,"Cap.ico     "
# ----------------------------------------
# Difference at line 311:
#   File 1: 6,.094,.557,"Cards.ico   "
#   File 2: 6,.8231884,.4650456,"Cards.ico   "
# ----------------------------------------
# Difference at line 318:
# ...

# %%
path_file1 = "../object location data/Alle data GOED/C01b.res"
path_file2 = "../object location data/Alle data GOED/controle01b.res"
compare_res_files(path_file1, path_file2)
# Out:
# Difference at line 39:
#   File 1: 1,.62,.042,"Bal.ico     "
#   File 2: 1,.065,.971,"Bal.ico     "
# ----------------------------------------
# Difference at line 42:
#   File 1: 2,.449,.235,"BALLON.ICO  "
#   File 2: 2,.9072464,.6048632,"BALLON.ICO  "
# ----------------------------------------
# Difference at line 45:
#   File 1: 3,.963,.298,"BANAAN.ICO  "
#   File 2: 3,.177,.797,"BANAAN.ICO  "
# ----------------------------------------
# Difference at line 48:
#   File 1: 4,.293,.425,"Bed.ico     "
#   File 2: 4,.963,.298,"Bed.ico     "
# ----------------------------------------
# Difference at line 51:
#   File 1: 5,.177,.797,"BEERTJE.ICO "
#   File 2: 5,.6811594,.9300912,"BEERTJE.ICO "
# ----------------------------------------
# Difference at line 55:
#   File 1: 6,.043,.494,"Beetle.ico  "
#   File 2: 6,.293,.425,"Beetle.ico  "
# ----------------------------------------
# Difference at line 58:
#   File 1: 7,.6811594,.9300912,"BEKER.ICO   "
# ...
