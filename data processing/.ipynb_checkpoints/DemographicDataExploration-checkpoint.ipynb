# %%
import pyreadstat
import pandas as pd
import numpy as np
from pathlib import Path
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu

# %% [markdown]
# # Demographic data exploration
#
# The following file aims to visualize and understand better the available data of each participant

# %%
df, meta = pyreadstat.read_sav("../../object location data/Definitieve data file Data masterthesis GOED.sav")
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Columns: 203 entries, ID to Nulscores
# dtypes: float64(183), str(20)
# memory usage: 63.6 KB
#     ID  sekse  groep  leeftijd  opleiding  RBMT  Stroop_k1  Stroop_k2  \
# 0  1.0    1.0    0.0      58.0        6.0  55.0       54.0       69.0
# 1  2.0    0.0    0.0      65.0        3.0   NaN      104.0      132.0
# 2  3.0    0.0    0.0      54.0        5.0  58.0       46.0      100.0
# 3  4.0    0.0    0.0      58.0        5.0  54.0       60.0       79.0
# 4  5.0    0.0    0.0      53.0        3.0  53.0       68.0       80.0
#
#    Stroop_k3  IF_Stroop  ...  filter_$  Diff_score_NT  Diff_score_sRI  \
# 0       96.0      109.0  ...       1.0      -0.033016        0.064343
# 1      350.0        NaN  ...       1.0       0.881896        0.515170
# 2      134.0      147.0  ...       1.0       0.301841        0.318815
# 3      110.0      125.0  ...       1.0       0.160216        0.197832
# 4      154.0      132.0  ...       1.0      -0.006237        0.161231
#
#    Diff_score_dRI  Diff_score_delay  perc_diffscore_NT  perc_diffscore_sRI  \
# 0        0.054757         -0.118331          -3.301575            6.434347
# 1        0.189972         -0.060228          88.189608           51.516973
# 2        1.085214          0.689474          30.184108           31.881517
# 3        0.250294         -0.099256          16.021604           19.783162
# 4       -0.087561          0.472483          -0.623707           16.123073
#
#    perc_diffscore_dRI  perc_diffscore_delay  Nulscores
# 0            5.475653            -11.833126        0.0
# 1           18.997194             -6.022760        0.0
# 2          108.521447             68.947383        0.0
# 3           25.029393             -9.925591        0.0
# 4           -8.756147             47.248282        0.0
#
# [5 rows x 203 columns]

# %%
df_meta = pd.DataFrame({
    "name": meta.column_names,
    "label": meta.column_labels,
    "measure": [meta.variable_measure.get(col) for col in meta.column_names],
})

# %%
# Group variables by type
print(np.unique(df_meta.measure))
nominal_var = [df_meta['name'][i] for i in range(len(df_meta)) if df_meta['measure'][i] == "nominal"]
ordinal_var = [df_meta['name'][i] for i in range(len(df_meta)) if df_meta['measure'][i] == "ordinal"]
scale_var = [df_meta['name'][i] for i in range(len(df_meta)) if df_meta['measure'][i] == "scale"]
# Out:
# ['nominal' 'ordinal' 'scale']

# %% [markdown]
# ## Filtered participants
#
# Explore conditions to filter participants

# %%
df.loc[df["filter_$"] == 0].iloc[:, :21].T
# Out:
#                         7      9        11     25     31
# ID                     8.0   10.0   12.000   26.0   32.0
# sekse                  0.0    0.0    0.000    0.0    0.0
# groep                  0.0    0.0    0.000    1.0    1.0
# leeftijd              52.0   58.0   57.000   67.0   67.0
# opleiding              NaN    NaN    4.000    5.0    5.0
# RBMT                   NaN    NaN   53.000    NaN    NaN
# Stroop_k1             65.0   56.0   67.000   54.0   48.0
# Stroop_k2             63.0   65.0   72.000   70.0   61.0
# Stroop_k3            122.0  103.0  121.000  104.0  113.0
# IF_Stroop              NaN  117.0  119.000  120.0  104.0
# Tscore_IF_Stroop       NaN   56.0   49.000   57.0   46.0
# percent_IF_Stroop      NaN   73.0   46.000   76.0   34.0
# NLV                    NaN   76.0   70.000  123.0  129.0
# TIQ_WAIS               NaN    NaN   75.000    NaN    NaN
# VBI_WAIS               NaN   91.0   79.000    NaN    NaN
# PRI_WAIS               NaN   83.0   83.000    NaN    NaN
# WG_WAIS                NaN   71.0   83.000    NaN    NaN
# PF_LLT                 NaN    NaN   59.000    NaN    NaN
# percent_PF_LLT         NaN    NaN   13.000    NaN    NaN
# leerind_LLT            NaN    NaN    0.265    NaN    NaN
# percent_leerind_LLT    NaN    NaN   13.000    NaN    NaN

# %% [markdown]
# - Education level filtering

# %%
df.loc[df["opleiding"] <= 2].iloc[:, :21].T
# Out:
#                          5      21       22
# ID                     6.00   22.0   23.000
# sekse                  0.00    1.0    0.000
# groep                  0.00    0.0    0.000
# leeftijd              64.00   62.0   75.000
# opleiding              2.00    2.0    2.000
# RBMT                  59.00   57.0   57.000
# Stroop_k1             60.00  120.0   95.000
# Stroop_k2             77.00  140.0  116.000
# Stroop_k3            113.00  264.0  194.000
# IF_Stroop            123.00  234.0  232.000
# Tscore_IF_Stroop      54.00   47.0   55.000
# percent_IF_Stroop     66.00   38.0   69.000
# NLV                  107.00    NaN   84.000
# TIQ_WAIS              81.00   60.0   67.000
# VBI_WAIS             100.00   68.0   74.000
# PRI_WAIS              69.00   66.0   79.000
# WG_WAIS              105.00   68.0   80.000
# PF_LLT                70.00  141.0  100.000
# percent_PF_LLT         4.00    1.0    4.000
# leerind_LLT            0.14    0.1    0.054
# percent_leerind_LLT    4.00    8.0   13.000

# %% [markdown]
# - Premorvid IQ estimation filtering

# %%
df.loc[(df["NLV"] < 80) | (df["NLV"] > 120)].iloc[:, :21].T
# Out:
#                          4        6      9        11      23     25     31
# ID                     5.00    7.000   10.0   12.000   24.00   26.0   32.0
# sekse                  0.00    1.000    0.0    0.000    0.00    0.0    0.0
# groep                  0.00    0.000    0.0    0.000    0.00    1.0    1.0
# leeftijd              53.00   67.000   58.0   57.000   59.00   67.0   67.0
# opleiding              3.00    4.000    NaN    4.000    4.00    5.0    5.0
# RBMT                  53.00   55.000    NaN   53.000   52.00    NaN    NaN
# Stroop_k1             68.00   75.000   56.0   67.000   62.00   54.0   48.0
# Stroop_k2             80.00   79.000   65.0   72.000   72.00   70.0   61.0
# Stroop_k3            154.00  193.000  103.0  121.000  190.00  104.0  113.0
# IF_Stroop            132.00  137.000  117.0  119.000     NaN  120.0  104.0
# Tscore_IF_Stroop      44.00   39.000   56.0   49.000     NaN   57.0   46.0
# percent_IF_Stroop     27.00   14.000   73.0   46.000     NaN   76.0   34.0
# NLV                   75.00   78.000   76.0   70.000   67.00  123.0  129.0
# TIQ_WAIS              72.00   64.000    NaN   75.000   59.00    NaN    NaN
# VBI_WAIS              83.00   70.000   91.0   79.000   72.00    NaN    NaN
# PRI_WAIS              77.00   77.000   83.0   83.000   64.00    NaN    NaN
# WG_WAIS               83.00   74.000   71.0   83.000   68.00    NaN    NaN
# PF_LLT                83.00   67.000    NaN   59.000   91.00    NaN    NaN
# percent_PF_LLT         4.00   13.000    NaN   13.000    4.00    NaN    NaN
# leerind_LLT            0.12    0.195    NaN    0.265    0.07    NaN    NaN
# percent_leerind_LLT    4.00   18.000    NaN   13.000    4.00    NaN    NaN

# %% [markdown]
# - Postmorvid IQ estimation filtering

# %%
df.loc[(df["TIQ_WAIS"] <= 80)].iloc[:, :21].T
# Out:
#                           2       4        6      8        11       12     21  \
# ID                     3.000    5.00    7.000    9.0   12.000   13.000   22.0
# sekse                  0.000    0.00    1.000    1.0    0.000    0.000    1.0
# groep                  0.000    0.00    0.000    0.0    0.000    0.000    0.0
# leeftijd              54.000   53.00   67.000   44.0   57.000   63.000   62.0
# opleiding              5.000    3.00    4.000    3.0    4.000    5.000    2.0
# RBMT                  58.000   53.00   55.000   56.0   53.000   54.000   57.0
# Stroop_k1             46.000   68.00   75.000   42.0   67.000   58.000  120.0
# Stroop_k2            100.000   80.00   79.000   49.0   72.000   68.000  140.0
# Stroop_k3            134.000  154.00  193.000   85.0  121.000  121.000  264.0
# IF_Stroop            147.000  132.00  137.000   84.0  119.000  114.000  234.0
# Tscore_IF_Stroop      53.000   44.00   39.000   49.0   49.000   47.000   47.0
# percent_IF_Stroop     62.000   27.00   14.000   46.0   46.000   38.000   38.0
# NLV                  106.000   75.00   78.000   92.0   70.000   98.000    NaN
# TIQ_WAIS              74.000   72.00   64.000   79.0   75.000   76.000   60.0
# VBI_WAIS              74.000   83.00   70.000   86.0   79.000   91.000   68.0
# PRI_WAIS              68.000   77.00   77.000   72.0   83.000   66.000   66.0
# WG_WAIS              100.000   83.00   74.000  103.0   83.000   89.000   68.0
# PF_LLT                60.000   83.00   67.000    NaN   59.000   54.000  141.0
# percent_PF_LLT         4.000    4.00   13.000    NaN   13.000   13.000    1.0
# leerind_LLT            0.105    0.12    0.195    NaN    0.265    0.192    0.1
# percent_leerind_LLT    1.000    4.00   18.000    NaN   13.000    8.000    8.0
#
#                           22      23      35
# ID                    23.000   24.00  36.000
# sekse                  0.000    0.00   0.000
# groep                  0.000    0.00   0.000
# leeftijd              75.000   59.00  54.000
# opleiding              2.000    4.00   3.000
# RBMT                  57.000   52.00  78.000
# Stroop_k1             95.000   62.00     NaN
# Stroop_k2            116.000   72.00     NaN
# Stroop_k3            194.000  190.00     NaN
# IF_Stroop            232.000     NaN     NaN
# Tscore_IF_Stroop      55.000     NaN     NaN
# percent_IF_Stroop     69.000     NaN     NaN
# NLV                   84.000   67.00  92.000
# TIQ_WAIS              67.000   59.00  69.000
# VBI_WAIS              74.000   72.00  98.000
# PRI_WAIS              79.000   64.00  60.000
# WG_WAIS               80.000   68.00  83.000
# PF_LLT               100.000   91.00  59.000
# percent_PF_LLT         4.000    4.00   5.000
# leerind_LLT            0.054    0.07   0.259
# percent_leerind_LLT   13.000    4.00   4.000

# %% [markdown]
# ## . Nominal variables (categorical)

# %%
print("Nominal: ", nominal_var)
# Out:
# Nominal:  ['ID', 'sekse', 'groep', 'no_obj.1', 'no_obj.2', 'no_obj.3', 'no_obj.4', 'no_obj.5', 'no_obj.6', 'no_obj.7', 'no_obj.8', 'no_obj.9', 'no_obj.10', 'no_obj.11', 'no_obj.12', 'no_obj.13', 'no_obj.14', 'no_obj.15', 'no_obj.16', 'no_obj.17', 'no_obj.18', 'no_obj.19', 'no_obj.20', 'permut.1', 'permut.2', 'permut.3', 'permut.4', 'permut.5', 'permut.6', 'permut.7', 'permut.8', 'permut.9', 'permut.10', 'permut.11', 'permut.12', 'permut.13', 'permut.14', 'permut.15', 'permut.16', 'permut.17', 'permut.18', 'permut.19', 'permut.20', 'subst.1', 'subst.2', 'subst.3', 'subst.4', 'subst.5', 'subst.6', 'subst.7', 'subst.8', 'subst.9', 'subst.10', 'subst.11', 'subst.12', 'subst.13', 'subst.14', 'subst.15', 'subst.16', 'subst.17', 'subst.18', 'subst.19', 'subst.20', 'swap.1', 'swap.2', 'swap.3', 'swap.4', 'swap.5', 'swap.6', 'swap.7', 'swap.8', 'swap.9', 'swap.10', 'swap.11', 'swap.12', 'swap.13', 'swap.14', 'swap.15', 'swap.16', 'swap.17', 'swap.18', 'swap.19', 'swap.20', 'perc_inc.1', 'perc_inc.2', 'perc_inc.3', 'perc_inc.4', 'perc_inc.5', 'perc_inc.6', 'perc_inc.7', 'perc_inc.8', 'perc_inc.9', 'perc_inc.10', 'perc_inc.11', 'perc_inc.12', 'perc_inc.13', 'perc_inc.14', 'perc_inc.15', 'perc_inc.16', 'perc_inc.17', 'perc_inc.18', 'perc_inc.19', 'perc_inc.20', 'filter_$', 'Nulscores']

# %%
df_nominal = df[nominal_var]
desc = df_nominal.describe().T

desc["n_unique"] = df_nominal.nunique()
missing_codes = [9999, 9999.00, 8888]
desc["n_missing"] = df_nominal.replace(missing_codes, np.nan).isna().sum()

with pd.option_context('display.max_rows', None):
    display(desc)
# Out:
#              count        mean        std    min     25%    50%     75%  \
# ID            40.0   20.500000  11.690452    1.0   10.75   20.5   30.25
# sekse         40.0    0.275000   0.452203    0.0    0.00    0.0    1.00
# groep         40.0    0.500000   0.506370    0.0    0.00    0.5    1.00
# no_obj.1      39.0    2.000000   0.000000    2.0    2.00    2.0    2.00
# no_obj.2      39.0    2.000000   0.000000    2.0    2.00    2.0    2.00
# no_obj.3      39.0    2.000000   0.000000    2.0    2.00    2.0    2.00
# no_obj.4      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.5      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.6      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.7      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.8      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.9      39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.10     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.11     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.12     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.13     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.14     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.15     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.16     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.17     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.18     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.19     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# no_obj.20     39.0   10.000000   0.000000   10.0   10.00   10.0   10.00
# subst.1       39.0    0.000000   0.000000    0.0    0.00    0.0    0.00
# subst.2       39.0    0.000000   0.000000    0.0    0.00    0.0    0.00
# subst.3       39.0    0.000000   0.000000    0.0    0.00    0.0    0.00
# subst.4       39.0    3.692308   3.532956    0.0    0.00    3.0    7.00
# subst.5       39.0    5.051282   2.999550    0.0    3.00    6.0    7.00
# subst.6       39.0    4.974359   3.391066    0.0    3.00    5.0    8.00
# subst.7       39.0    2.794872   3.262058    0.0    0.00    3.0    5.00
# subst.8       39.0    3.871795   3.540588    0.0    0.00    4.0    7.00
# subst.9       39.0    4.461538   3.102174    0.0    3.00    5.0    7.00
# subst.10      39.0    4.205128   2.966297    0.0    3.00    4.0    6.00
# subst.11      39.0    5.076923   2.548318    0.0    4.00    5.0    7.00
# subst.12      39.0    5.846154   2.851947    0.0    4.00    6.0    8.00
# subst.13      39.0    3.589744   3.032438    0.0    0.00    3.0    6.00
# subst.14      39.0    3.589744   3.242140    0.0    0.00    4.0    6.00
# subst.15      39.0    4.974359   2.933358    0.0    3.50    5.0    7.00
# subst.16      39.0    3.923077   3.374709    0.0    0.00    4.0    7.00
# subst.17      39.0    4.461538   3.560353    0.0    0.00    5.0    8.00
# subst.18      39.0    3.153846   3.248793    0.0    0.00    3.0    5.50
# subst.19      39.0    3.282051   3.300309    0.0    0.00    4.0    6.00
# subst.20      39.0    0.102564   0.640513    0.0    0.00    0.0    0.00
# swap.1        39.0    0.179487   0.388776    0.0    0.00    0.0    0.00
# swap.2        39.0    0.128205   0.338688    0.0    0.00    0.0    0.00
# swap.3        39.0    0.769231   0.426833    0.0    1.00    1.0    1.00
# swap.4        39.0    0.435897   0.680359    0.0    0.00    0.0    1.00
# swap.5        39.0    0.538462   0.600270    0.0    0.00    0.0    1.00
# swap.6        39.0    0.743590   0.818148    0.0    0.00    1.0    1.00
# swap.7        39.0    0.461538   0.789609    0.0    0.00    0.0    1.00
# swap.8        39.0    0.538462   0.755546    0.0    0.00    0.0    1.00
# swap.9        39.0    0.564103   0.680359    0.0    0.00    0.0    1.00
# swap.10       39.0    0.564103   0.717997    0.0    0.00    0.0    1.00
# swap.11       39.0    0.538462   0.682339    0.0    0.00    0.0    1.00
# swap.12       39.0    0.512821   0.643665    0.0    0.00    0.0    1.00
# swap.13       39.0    0.641026   0.777553    0.0    0.00    0.0    1.00
# swap.14       39.0    0.564103   0.717997    0.0    0.00    0.0    1.00
# swap.15       39.0    0.487179   0.683328    0.0    0.00    0.0    1.00
# swap.16       39.0    0.538462   0.600270    0.0    0.00    0.0    1.00
# swap.17       39.0    0.564103   0.753758    0.0    0.00    0.0    1.00
# swap.18       39.0    0.589744   0.785324    0.0    0.00    0.0    1.00
# swap.19       39.0    0.794872   0.695076    0.0    0.00    1.0    1.00
# swap.20       39.0    0.025641   0.160128    0.0    0.00    0.0    0.00
# perc_inc.1    39.0   87.179487  24.915512    0.0  100.00  100.0  100.00
# perc_inc.2    39.0   87.179487  27.429212    0.0  100.00  100.0  100.00
# perc_inc.3    39.0  100.000000   0.000000  100.0  100.00  100.0  100.00
# perc_inc.4    39.0   89.230769  11.094004   70.0   80.00   90.0  100.00
# perc_inc.5    39.0   93.076923   7.997975   70.0   90.00   90.0  100.00
# perc_inc.6    39.0   91.794872   9.139790   70.0   90.00   90.0  100.00
# perc_inc.7    39.0   86.923077  11.732511   50.0   80.00   90.0  100.00
# perc_inc.8    39.0   90.512821  13.367029   50.0   90.00  100.0  100.00
# perc_inc.9    39.0   90.256410   9.864124   60.0   80.00   90.0  100.00
# perc_inc.10   39.0   91.025641  10.461677   60.0   85.00   90.0  100.00
# perc_inc.11   39.0   91.538462   9.329766   70.0   85.00   90.0  100.00
# perc_inc.12   39.0   94.102564   7.510676   70.0   90.00  100.0  100.00
# perc_inc.13   39.0   90.000000  11.002392   60.0   90.00   90.0  100.00
# perc_inc.14   39.0   85.897436  12.294190   40.0   80.00   90.0   90.00
# perc_inc.15   39.0   92.307692  11.346583   50.0   90.00  100.0  100.00
# perc_inc.16   39.0   86.923077  13.602215   50.0   80.00   90.0  100.00
# perc_inc.17   39.0   90.256410  12.027858   60.0   80.00  100.0  100.00
# perc_inc.18   39.0   93.076923   8.930682   70.0   90.00  100.0  100.00
# perc_inc.19   39.0   92.307692   9.586597   60.0   90.00   90.0  100.00
# perc_inc.20   39.0   32.307692  21.940294    0.0   20.00   30.0   50.00
# filter_$      40.0    0.875000   0.334932    0.0    1.00    1.0    1.00
# Nulscores     40.0    0.000000   0.000000    0.0    0.00    0.0    0.00
#
#                max  n_unique  n_missing
# ID            40.0        40          0
# sekse          1.0         2          0
# groep          1.0         2          0
# no_obj.1       2.0         1          1
# no_obj.2       2.0         1          1
# no_obj.3       2.0         1          1
# no_obj.4      10.0         1          1
# no_obj.5      10.0         1          1
# no_obj.6      10.0         1          1
# no_obj.7      10.0         1          1
# no_obj.8      10.0         1          1
# no_obj.9      10.0         1          1
# no_obj.10     10.0         1          1
# no_obj.11     10.0         1          1
# no_obj.12     10.0         1          1
# no_obj.13     10.0         1          1
# no_obj.14     10.0         1          1
# no_obj.15     10.0         1          1
# no_obj.16     10.0         1          1
# no_obj.17     10.0         1          1
# no_obj.18     10.0         1          1
# no_obj.19     10.0         1          1
# no_obj.20     10.0         1          1
# subst.1        0.0         1          1
# subst.2        0.0         1          1
# subst.3        0.0         1          1
# subst.4       10.0         8          1
# subst.5       10.0         9          1
# subst.6       10.0         9          1
# subst.7       10.0         9          1
# subst.8       10.0         9          1
# subst.9       10.0         9          1
# subst.10      10.0         9          1
# subst.11       9.0         8          1
# subst.12      10.0         9          1
# subst.13       9.0         8          1
# subst.14      10.0         9          1
# subst.15      10.0         9          1
# subst.16       9.0         8          1
# subst.17      10.0         9          1
# subst.18       9.0         8          1
# subst.19       9.0         8          1
# subst.20       4.0         2          1
# swap.1         1.0         2          1
# swap.2         1.0         2          1
# swap.3         1.0         2          1
# swap.4         2.0         3          1
# swap.5         2.0         3          1
# swap.6         2.0         3          1
# swap.7         3.0         4          1
# swap.8         2.0         3          1
# swap.9         2.0         3          1
# swap.10        2.0         3          1
# swap.11        2.0         3          1
# swap.12        2.0         3          1
# swap.13        3.0         4          1
# swap.14        3.0         4          1
# swap.15        2.0         3          1
# swap.16        2.0         3          1
# swap.17        3.0         4          1
# swap.18        3.0         4          1
# swap.19        3.0         4          1
# swap.20        1.0         2          1
# perc_inc.1   100.0         3          1
# perc_inc.2   100.0         3          1
# perc_inc.3   100.0         1          1
# perc_inc.4   100.0         4          1
# perc_inc.5   100.0         4          1
# perc_inc.6   100.0         4          1
# perc_inc.7   100.0         6          1
# perc_inc.8   100.0         5          1
# perc_inc.9   100.0         5          1
# perc_inc.10  100.0         5          1
# perc_inc.11  100.0         4          1
# perc_inc.12  100.0         4          1
# perc_inc.13  100.0         5          1
# perc_inc.14  100.0         5          1
# perc_inc.15  100.0         5          1
# perc_inc.16  100.0         6          1
# perc_inc.17  100.0         5          1
# perc_inc.18  100.0         4          1
# perc_inc.19  100.0         5          1
# perc_inc.20   80.0         9          1
# filter_$       1.0         2          0
# Nulscores      0.0         1          0

# %% [markdown]
# ### Binary variables (gender and group)

# %%
gender_map = {0: "Man", 1: "Woman"}
group_map = {0: "KS", 1: "HC"}

gender = df["sekse"].map(gender_map)
group = df["groep"].map(group_map)

print("Counts table")
matrix_counts = (pd.crosstab(gender, group))
matrix_counts['Total'] = matrix_counts.sum(axis=1)
total_row = pd.DataFrame(matrix_counts.sum(axis=0)).T
total_row.index = ['Total']
matrix_counts = pd.concat([matrix_counts, total_row])
matrix_counts = matrix_counts.rename_axis(None, axis=1)
display(matrix_counts)

print("Percentatge table")
matrix_pct = pd.crosstab(gender, group, normalize="all") * 100
matrix_pct["Total"] = matrix_pct.sum(axis=1)
total_row = pd.DataFrame(matrix_pct.sum(axis=0)).T
total_row.index = ["Total"]
matrix_pct = pd.concat([matrix_pct, total_row])
matrix_pct = matrix_pct.rename_axis(None, axis=1)
display(matrix_pct.round(2))
# Out:
# Counts table
#        HC  KS  Total
# Man    14  15     29
# Woman   6   5     11
# Total  20  20     40
# Percentatge table
#          HC    KS  Total
# Man    35.0  37.5   72.5
# Woman  15.0  12.5   27.5
# Total  50.0  50.0  100.0

# %%
exclude_ids = [8, 10, 12, 26, 32, 40]
df_filtered = df[~df["ID"].isin(exclude_ids)]

gender = df_filtered["sekse"].map(gender_map)
group = df_filtered["groep"].map(group_map)

print("Counts table filtered participants")
matrix_counts = (pd.crosstab(gender, group))
matrix_counts['Total'] = matrix_counts.sum(axis=1)
total_row = pd.DataFrame(matrix_counts.sum(axis=0)).T
total_row.index = ['Total']
matrix_counts = pd.concat([matrix_counts, total_row])
matrix_counts = matrix_counts.rename_axis(None, axis=1)
display(matrix_counts)

print("Percentatge table filtered participants")
matrix_pct = pd.crosstab(gender, group, normalize="all") * 100
matrix_pct["Total"] = matrix_pct.sum(axis=1)
total_row = pd.DataFrame(matrix_pct.sum(axis=0)).T
total_row.index = ["Total"]
matrix_pct = pd.concat([matrix_pct, total_row])
matrix_pct = matrix_pct.rename_axis(None, axis=1)
display(matrix_pct.round(2))
# Out:
# Counts table filtered participants
#        HC  KS  Total
# Man    12  12     24
# Woman   5   5     10
# Total  17  17     34
# Percentatge table filtered participants
#           HC     KS   Total
# Man    35.29  35.29   70.59
# Woman  14.71  14.71   29.41
# Total  50.00  50.00  100.00

# %% [markdown]
# ## . Ordinal variables (categorical with order)

# %%
print("Ordinal: ", ordinal_var)
# Out:
# Ordinal:  ['opleiding']

# %%
print("Unique values: ", len(np.unique(df["opleiding"])))
fig, ax = plt.subplots(2,2, figsize=(20, 15)) 

age_counts = df["opleiding"].value_counts().sort_index()
ax[0,0].bar(age_counts.index, age_counts.values)
ax[0,0].set_xlabel("Educational level")
ax[0,0].set_ylabel("Counts")
ax[0,0].set_title("Total educational level counts")

levels = sorted(df["opleiding"].unique())
x = np.arange(len(levels))  # positions on x-axis
width = 0.35                # width of each bar
# Split by group
counts_0 = (df[df["groep"] == 0]["opleiding"].value_counts().reindex(levels, fill_value=0))
counts_1 = (df[df["groep"] == 1]["opleiding"].value_counts().reindex(levels, fill_value=0))
ax[0,1].bar(x - width/2, counts_0.values, width, label="Group 0")
ax[0,1].bar(x + width/2, counts_1.values, width, label="Group 1")
ax[0,1].set_xlabel("Educational level")
ax[0,1].set_ylabel("Counts")
ax[0,1].set_xticks(x, levels, rotation=45, ha="right")
ax[0,1].set_title("Educational level counts by Group")
ax[0,1].legend(['KS', 'HC'])

# Split by gender
counts_0 = (df[df["sekse"] == 0]["opleiding"].value_counts().reindex(levels, fill_value=0))
counts_1 = (df[df["sekse"] == 1]["opleiding"].value_counts().reindex(levels, fill_value=0))
ax[1,0].bar(x - width/2, counts_0.values, width, label="Group 0")
ax[1,0].bar(x + width/2, counts_1.values, width, label="Group 1")
ax[1,0].set_xlabel("Educational level")
ax[1,0].set_ylabel("Counts")
ax[1,0].set_xticks(x, levels, rotation=45, ha="right")
ax[1,0].set_title("Educational level counts by Gender")
ax[1,0].legend(['Man', 'Woman'])

# Split by gender-group combintions
width = 0.2                
combinations = [(0, 0, "KS - Man"),(0, 1, "KS - Woman"),(1, 0, "HC - Man"),(1, 1, "HC - Woman"),]
for i, (groep, sekse, label) in enumerate(combinations):
    counts = (df[(df["groep"] == groep) & (df["sekse"] == sekse)]["opleiding"].value_counts().reindex(levels, fill_value=0))
    ax[1,1].bar(x + (i - 1.5) * width, counts.values, width, label=label)
ax[1,1].set_xlabel("Educational level")
ax[1,1].set_ylabel("Counts")
ax[1,1].set_xticks(x, levels, rotation=45, ha="right")
ax[1,1].set_title("Educational level counts by Group and Gender")
ax[1,1].legend()
plt.show()
# Out:
# Unique values:  6

# %%
# Check if education level among KS nad HC are well paired
ks = df[df["groep"] == 0]["opleiding"]
hc = df[df["groep"] == 1]["opleiding"]
missing_ks = ks.isna().sum()
missing_hc = hc.isna().sum()
print(f"Missing values in KS group: {missing_ks}")
print(f"Missing values in HC group: {missing_hc}")

ks_clean = ks.dropna()
hc_clean = hc.dropna()
stat, p = mannwhitneyu(ks_clean, hc_clean, alternative='two-sided')
print("Mann-Whitney U statistic:", stat)
print("p-value:", p)
# Out:
# Missing values in KS group: 3
# Missing values in HC group: 0
# Mann-Whitney U statistic: 65.5
# p-value: 0.0006727072878904095

# %% [markdown]
# ## . Quantitative/scale variables

# %%
print("Scale: ", scale_var)
# Out:
# Scale:  ['leeftijd', 'RBMT', 'Stroop_k1', 'Stroop_k2', 'Stroop_k3', 'IF_Stroop', 'Tscore_IF_Stroop', 'percent_IF_Stroop', 'NLV', 'TIQ_WAIS', 'VBI_WAIS', 'PRI_WAIS', 'WG_WAIS', 'PF_LLT', 'percent_PF_LLT', 'leerind_LLT', 'percent_leerind_LLT', 'time.1', 'time.2', 'time.3', 'time.4', 'time.5', 'time.6', 'time.7', 'time.8', 'time.9', 'time.10', 'time.11', 'time.12', 'time.13', 'time.14', 'time.15', 'time.16', 'time.17', 'time.18', 'time.19', 'time.20', 'abs_err.1', 'abs_err.2', 'abs_err.3', 'abs_err.4', 'abs_err.5', 'abs_err.6', 'abs_err.7', 'abs_err.8', 'abs_err.9', 'abs_err.10', 'abs_err.11', 'abs_err.12', 'abs_err.13', 'abs_err.14', 'abs_err.15', 'abs_err.16', 'abs_err.17', 'abs_err.18', 'abs_err.19', 'abs_err.20', 'bestft.1', 'bestft.2', 'bestft.3', 'bestft.4', 'bestft.5', 'bestft.6', 'bestft.7', 'bestft.8', 'bestft.9', 'bestft.10', 'bestft.11', 'bestft.12', 'bestft.13', 'bestft.14', 'bestft.15', 'bestft.16', 'bestft.17', 'bestft.18', 'bestft.19', 'bestft.20', 'abs_err_NT', 'abs_err_simRI', 'abs_err_controlNT', 'abs_err_divRI', 'abs_err_delay', 'abs_err_baseline', 'bestfit_NT', 'bestfit_sRI', 'bestfit_controlNT', 'bestfit_divRI', 'bestfit_delay', 'bestfit_baseline', 'Diff_score_NT', 'Diff_score_sRI', 'Diff_score_dRI', 'Diff_score_delay', 'perc_diffscore_NT', 'perc_diffscore_sRI', 'perc_diffscore_dRI', 'perc_diffscore_delay']

# %%
df_scale = df[scale_var]
desc = df_scale.describe().T

desc["n_unique"] = df_scale.nunique()
missing_codes = [9999, 9999.00, 8888]
desc["n_missing"] = df_scale.replace(missing_codes, np.nan).isna().sum()

with pd.option_context('display.max_rows', None):
    display(desc)
# Out:
#                       count           mean           std           min  \
# leeftijd               40.0      58.825000      7.030656     43.000000
# RBMT                   14.0      57.214286      6.435222     52.000000
# Stroop_k1              38.0      57.105263     18.047669     38.000000
# Stroop_k2              38.0      71.105263     21.226945     43.000000
# Stroop_k3              38.0     123.894737     59.927339     66.000000
# IF_Stroop              34.0     115.088235     34.563396     72.000000
# Tscore_IF_Stroop       34.0      53.205882      7.853891     39.000000
# percent_IF_Stroop      34.0      59.117647     23.683218     14.000000
# NLV                    35.0      96.857143     15.306944     67.000000
# TIQ_WAIS               13.0      73.769231     10.465450     59.000000
# VBI_WAIS               14.0      85.571429     13.893630     68.000000
# PRI_WAIS               14.0      74.500000      9.653616     60.000000
# WG_WAIS                14.0      86.071429     14.171826     68.000000
# PF_LLT                 13.0      86.615385     28.546858     54.000000
# percent_PF_LLT         13.0       5.307692      4.589565      1.000000
# leerind_LLT            13.0       0.139231      0.074458      0.050000
# percent_leerind_LLT    13.0       6.230769      5.449065      1.000000
# time.1                 39.0   19239.358974  12104.401428   5225.000000
# time.2                 39.0   14112.897436  15945.487570   4253.000000
# time.3                 39.0   19942.025641  11352.059360   8341.000000
# time.4                 39.0   85744.820513  66104.784661  23576.000000
# time.5                 39.0   85910.461538  53045.761418  33046.000000
# time.6                 39.0   90035.102564  58781.763103  31964.000000
# time.7                 39.0   74948.282051  47568.702869  26614.000000
# time.8                 39.0   78547.282051  53762.849597  24344.000000
# time.9                 39.0   85168.846154  63570.399850  26378.000000
# time.10                39.0   71437.974359  48869.650136  23497.000000
# time.11                39.0   73886.820513  42898.418388  25218.000000
# time.12                39.0   82798.410256  47100.626939  27285.000000
# time.13                39.0   69253.538462  39301.725389  27560.000000
# time.14                39.0   69208.307692  45637.791901  22416.000000
# time.15                39.0   72270.461538  40789.005831  24470.000000
# time.16                39.0   69237.435897  42818.657910  21539.000000
# time.17                39.0   78552.230769  53999.331335  23201.000000
# time.18                39.0   68652.512821  40903.599634  21447.000000
# time.19                39.0   76983.282051  49462.718691  24558.000000
# time.20                39.0  137088.282051  85712.624376  58395.000000
# abs_err.1              39.0      65.657199     44.636526     18.481284
# abs_err.2              39.0      72.882530     53.565560      8.526919
# abs_err.3              39.0     132.269347     37.823634     29.797813
# abs_err.4              39.0     504.181280    273.988940    117.397338
# abs_err.5              39.0     657.302650    271.169415    209.948596
# abs_err.6              39.0     675.418186    255.422465    213.166160
# abs_err.7              39.0     450.579304    280.060075    134.387214
# abs_err.8              39.0     534.610222    263.928524     97.646120
# abs_err.9              39.0     587.541514    268.458742    125.282242
# abs_err.10             39.0     496.082637    231.439461    161.486182
# abs_err.11             39.0     577.295404    206.560894    121.030667
# abs_err.12             39.0     647.703114    225.867384    188.604947
# abs_err.13             39.0     492.051271    237.738487    149.937892
# abs_err.14             39.0     483.998696    237.365403    112.826339
# abs_err.15             39.0     571.546811    247.237559    132.780585
# abs_err.16             39.0     529.214059    285.471295    134.580674
# abs_err.17             39.0     582.576387    300.966333    169.092669
# abs_err.18             39.0     456.897554    237.692180    128.388285
# abs_err.19             39.0     510.267350    273.968144    139.299944
# abs_err.20             39.0     103.196125    104.771952     34.843383
# bestft.1               39.0      56.279354     34.456940     18.481284
# bestft.2               39.0      60.461296     37.368402      8.526920
# bestft.3               39.0      78.704633     40.031251     23.970001
# bestft.4               39.0     276.853919     88.156283    117.397338
# bestft.5               39.0     344.652652    110.865471    164.625389
# bestft.6               39.0     314.985704    128.938140    200.426470
# bestft.7               39.0     286.328588    128.526648    134.387212
# bestft.8               39.0     344.791766    126.518686     97.646118
# bestft.9               39.0     325.252223    133.860406    125.282242
# bestft.10              39.0     281.780615    111.862196    150.521227
# bestft.11              39.0     289.146256    103.586173    121.030666
# bestft.12              39.0     300.924922    113.605019    182.794400
# bestft.13              39.0     312.779454    144.083563    149.937891
# bestft.14              39.0     299.517377    127.192081    112.826338
# bestft.15              39.0     327.515732    135.033325    132.780585
# bestft.16              39.0     300.732718    128.969879     89.661760
# bestft.17              39.0     337.018514    136.186674    141.843890
# bestft.18              39.0     302.281468    108.250534    128.388284
# bestft.19              39.0     305.033068    109.948694    139.299946
# bestft.20              39.0      93.009809     48.182911     34.843384
# abs_err_NT             39.0     617.299027    206.009008    238.756143
# abs_err_simRI          39.0     661.560650    217.868406    243.106583
# abs_err_controlNT      39.0     509.304459    236.280433    170.972027
# abs_err_divRI          39.0     579.544162    245.036373    147.165677
# abs_err_delay          39.0     546.421869    273.167464    154.196307
# abs_err_baseline       39.0     488.167684    232.177660    182.774129
# bestfit_NT             39.0     316.899454    100.359910    195.259966
# bestfit_sRI            39.0     307.955313    111.860332    215.387130
# bestfit_controlNT      39.0     322.154571    114.996702    151.038669
# bestfit_divRI          39.0     326.383977    129.709428    147.165676
# bestfit_delay          39.0     321.025791    118.661639    150.597158
# bestfit_baseline       39.0     293.459460    108.295693    161.952993
# Diff_score_NT          39.0       0.443940      0.539979     -0.298800
# Diff_score_sRI         39.0       0.503776      0.499138     -0.119166
# Diff_score_dRI         39.0       0.323497      0.301328     -0.218141
# Diff_score_delay       39.0       0.137688      0.249308     -0.228706
# perc_diffscore_NT      39.0      44.393974     53.997897    -29.880014
# perc_diffscore_sRI     39.0      50.377556     49.913775    -11.916553
# perc_diffscore_dRI     39.0      32.349732     30.132802    -21.814143
# perc_diffscore_delay   39.0      13.768819     24.930800    -22.870643
#
#                                25%            50%            75%  \
# leeftijd                 54.000000      58.000000      65.000000
# RBMT                     54.000000      55.500000      57.750000
# Stroop_k1                46.000000      51.000000      61.500000
# Stroop_k2                59.500000      68.000000      77.000000
# Stroop_k3                87.500000     106.000000     125.500000
# IF_Stroop                94.500000     110.500000     122.250000
# Tscore_IF_Stroop         47.000000      52.500000      57.000000
# percent_IF_Stroop        38.000000      60.000000      76.000000
# NLV                      87.000000      94.000000     107.000000
# TIQ_WAIS                 67.000000      74.000000      79.000000
# VBI_WAIS                 74.000000      84.500000      94.750000
# PRI_WAIS                 66.500000      74.500000      82.000000
# WG_WAIS                  75.500000      83.000000      97.250000
# PF_LLT                   60.000000      83.000000     100.000000
# percent_PF_LLT            2.000000       4.000000       5.000000
# leerind_LLT               0.070000       0.120000       0.192000
# percent_leerind_LLT       2.000000       4.000000       8.000000
# time.1                11990.000000   16387.000000   22160.000000
# time.2                 7029.000000    8650.000000   16398.000000
# time.3                12909.000000   16789.000000   22454.000000
# time.4                42849.500000   64242.000000  108701.000000
# time.5                45511.500000   72962.000000  106486.000000
# time.6                46564.500000   70157.000000  105933.500000
# time.7                39083.000000   59580.000000   97247.500000
# time.8                40502.500000   52525.000000  104863.000000
# time.9                39002.500000   55071.000000  124379.500000
# time.10               36949.500000   62151.000000   84166.500000
# time.11               40099.500000   62466.000000   88535.500000
# time.12               50340.000000   66167.000000   98198.000000
# time.13               37427.500000   59879.000000   83963.000000
# time.14               35504.500000   47206.000000   91503.500000
# time.15               39739.500000   53998.000000  110097.500000
# time.16               38979.500000   53494.000000   82488.000000
# time.17               38990.500000   65559.000000   94304.000000
# time.18               37292.000000   55534.000000   85568.000000
# time.19               40391.000000   61826.000000   97632.500000
# time.20               88541.500000  111847.000000  153973.000000
# abs_err.1                30.112088      49.182554      96.813178
# abs_err.2                38.643796      54.504570      87.240686
# abs_err.3               115.549614     137.159016     155.454303
# abs_err.4               300.548728     405.183617     687.816009
# abs_err.5               472.591922     637.408189     877.498299
# abs_err.6               464.524498     697.866043     846.621543
# abs_err.7               215.909306     354.167364     619.882724
# abs_err.8               318.198083     477.248932     695.439409
# abs_err.9               349.114091     558.303841     807.317213
# abs_err.10              306.617629     462.379570     664.774230
# abs_err.11              444.496383     546.718246     699.458089
# abs_err.12              496.053848     671.407608     801.114738
# abs_err.13              296.038204     432.427254     596.497831
# abs_err.14              322.002349     441.887774     598.412432
# abs_err.15              360.850128     622.165322     728.063832
# abs_err.16              266.843937     438.062556     784.638666
# abs_err.17              312.539096     497.014070     876.761735
# abs_err.18              263.532183     396.846972     596.519145
# abs_err.19              267.590687     467.604837     682.104160
# abs_err.20               67.264253      84.609023     101.937114
# bestft.1                 30.112088      48.680802      66.598536
# bestft.2                 37.764518      49.650340      79.641309
# bestft.3                 44.483555      75.886129     101.885591
# bestft.4                218.415954     261.703925     320.066110
# bestft.5                268.611902     324.440320     400.535839
# bestft.6                236.540202     276.250149     330.359910
# bestft.7                210.703290     254.382918     305.172625
# bestft.8                253.357477     345.092107     411.617698
# bestft.9                244.145917     304.006538     350.388876
# bestft.10               221.862301     260.268049     312.084740
# bestft.11               235.798899     266.919324     329.813138
# bestft.12               242.339277     263.227208     313.178890
# bestft.13               233.944927     270.630262     336.550176
# bestft.14               224.789581     276.310122     327.596313
# bestft.15               248.556332     317.943383     364.532415
# bestft.16               228.640167     279.824699     363.641820
# bestft.17               254.078877     333.588815     367.790943
# bestft.18               238.561280     281.937514     340.176694
# bestft.19               234.894720     292.037007     339.381580
# bestft.20                67.264253      84.609024     101.937115
# abs_err_NT              460.620090     646.138301     782.802597
# abs_err_simRI           490.066737     682.640055     798.621094
# abs_err_controlNT       336.471530     427.784992     689.342373
# abs_err_divRI           350.600179     609.853382     753.072043
# abs_err_delay           299.168489     472.145022     786.337844
# abs_err_baseline        287.516328     445.982444     684.483279
# bestfit_NT              260.215987     299.179555     359.146830
# bestfit_sRI             241.855551     273.187563     332.336144
# bestfit_controlNT       251.305164     305.333499     346.783926
# bestfit_divRI           254.194406     305.491776     357.280792
# bestfit_delay           241.650453     313.083802     352.319442
# bestfit_baseline        228.651176     275.827708     325.250775
# Diff_score_NT             0.119745       0.252083       0.585031
# Diff_score_sRI            0.156511       0.334087       0.735542
# Diff_score_dRI            0.130793       0.289103       0.491699
# Diff_score_delay         -0.019616       0.052478       0.267544
# perc_diffscore_NT        11.974451      25.208282      58.503094
# perc_diffscore_sRI       15.651092      33.408705      73.554202
# perc_diffscore_dRI       13.079265      28.910343      49.169875
# perc_diffscore_delay     -1.961552       5.247835      26.754438
#
#                                 max  n_unique  n_missing
# leeftijd                  75.000000        20          0
# RBMT                      78.000000        10         26
# Stroop_k1                120.000000        28          2
# Stroop_k2                140.000000        26          2
# Stroop_k3                350.000000        33          2
# IF_Stroop                234.000000        29          6
# Tscore_IF_Stroop          74.000000        19          6
# percent_IF_Stroop         99.000000        19          6
# NLV                      129.000000        28          5
# TIQ_WAIS                  95.000000        13         27
# VBI_WAIS                 116.000000        12         26
# PRI_WAIS                  94.000000        11         26
# WG_WAIS                  112.000000        11         26
# PF_LLT                   141.000000        12         27
# percent_PF_LLT            13.000000         5         27
# leerind_LLT                0.265000        12         27
# percent_leerind_LLT       18.000000         6         27
# time.1                 65715.000000        39          1
# time.2                 91682.000000        39          1
# time.3                 66248.000000        39          1
# time.4                377232.000000        39          1
# time.5                257245.000000        39          1
# time.6                292763.000000        39          1
# time.7                209248.000000        39          1
# time.8                214263.000000        39          1
# time.9                304512.000000        39          1
# time.10               252627.000000        39          1
# time.11               186135.000000        39          1
# time.12               218203.000000        39          1
# time.13               167146.000000        39          1
# time.14               199985.000000        39          1
# time.15               166884.000000        39          1
# time.16               178077.000000        39          1
# time.17               225329.000000        39          1
# time.18               174158.000000        39          1
# time.19               231197.000000        39          1
# time.20               404191.000000        39          1
# abs_err.1                193.726029        39          1
# abs_err.2                212.687960        39          1
# abs_err.3                208.764884        39          1
# abs_err.4               1069.317053        39          1
# abs_err.5               1104.388644        39          1
# abs_err.6               1176.058207        39          1
# abs_err.7               1290.544904        39          1
# abs_err.8               1064.308245        39          1
# abs_err.9               1239.448050        39          1
# abs_err.10              1153.115565        39          1
# abs_err.11              1172.947275        39          1
# abs_err.12              1136.594850        39          1
# abs_err.13              1124.388496        39          1
# abs_err.14              1212.467326        39          1
# abs_err.15              1179.840593        39          1
# abs_err.16              1140.077471        39          1
# abs_err.17              1124.325034        39          1
# abs_err.18              1033.907861        39          1
# abs_err.19              1099.947782        39          1
# abs_err.20               710.704789        39          1
# bestft.1                 155.227543        39          1
# bestft.2                 186.607280        39          1
# bestft.3                 189.872227        39          1
# bestft.4                 507.949360        39          1
# bestft.5                 665.421833        39          1
# bestft.6                 873.683296        39          1
# bestft.7                 865.335122        39          1
# bestft.8                 681.602928        39          1
# bestft.9                 915.905169        39          1
# bestft.10                780.748215        39          1
# bestft.11                686.033195        39          1
# bestft.12                830.355167        39          1
# bestft.13                956.395567        39          1
# bestft.14                879.808735        39          1
# bestft.15                982.969241        39          1
# bestft.16                845.082744        39          1
# bestft.17                874.497934        39          1
# bestft.18                721.306196        39          1
# bestft.19                729.320086        39          1
# bestft.20                313.438444        39          1
# abs_err_NT               995.958778        39          1
# abs_err_simRI           1056.139536        39          1
# abs_err_controlNT       1111.946469        39          1
# abs_err_divRI           1209.644321        39          1
# abs_err_delay           1112.136408        39          1
# abs_err_baseline        1059.591820        39          1
# bestfit_NT               675.727514        39          1
# bestfit_sRI              736.164016        39          1
# bestfit_controlNT        752.790183        39          1
# bestfit_divRI            949.437205        39          1
# bestfit_delay            801.909010        39          1
# bestfit_baseline         779.469534        39          1
# Diff_score_NT              1.986436        39          1
# Diff_score_sRI             1.945135        39          1
# Diff_score_dRI             1.180146        39          1
# Diff_score_delay           0.997187        39          1
# perc_diffscore_NT        198.643602        39          1
# perc_diffscore_sRI       194.513451        39          1
# perc_diffscore_dRI       118.014637        39          1
# perc_diffscore_delay      99.718684        39          1

# %% [markdown]
# ### . Age

# %%
print("Unique values: ", len(np.unique(df["leeftijd"])))
fig, ax = plt.subplots(1,3, figsize=(20, 5)) 
# plot bar plots
age_counts = df["leeftijd"].value_counts().sort_index()
ax[0].bar(age_counts.index, age_counts.values)
ax[0].set_xlabel("Age")
ax[0].set_ylabel("Counts")
ax[0].set_title("Age bar plot")

# plot histogram
ax[1].hist(df["leeftijd"], bins="auto", edgecolor="black")
ax[1].set_xlabel("Age")
ax[1].set_ylabel("Frequency")
ax[1].set_title("Age Distribution")
# plot violin plot
ax[2].violinplot(df["leeftijd"], showmeans=True, showmedians=True)
ax[2].set_ylabel("Age")
ax[2].set_xlabel("Relative frequency")
ax[2].set_title("Age Distribution")
plt.show()
# Out:
# Unique values:  20

# %%
variables = ["leeftijd"]
fig, axes = plt.subplots(nrows=len(variables),ncols=2,figsize=(12, 3 * len(variables)),sharex=False)

for i, var in enumerate(variables):
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan).dropna()
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan).dropna()

    # KS distribution
    sns.histplot(ks, kde=True, ax=axes[0])
    axes[0].set_title(f"{var} – KS")
    axes[0].set_ylabel("Count")

    # HC distribution
    sns.histplot(hc, kde=True, ax=axes[1])
    axes[1].set_title(f"{var} – HC")

plt.tight_layout()
plt.show()

# %%
print(f"KS: n={len(ks)}, mean={ks.mean():.2f}, SD={ks.std():.2f}")
print(f"HC: n={len(hc)}, mean={hc.mean():.2f}, SD={hc.std():.2f}")

t_stat, p_value = ttest_ind(ks, hc, equal_var=False)  # Welch's t-test
print(f"t = {t_stat:.3f}, p = {p_value:.4f}")
# Out:
# KS: n=20, mean=58.70, SD=6.78
# HC: n=20, mean=58.95, SD=7.44
# t = -0.111, p = 0.9122

# %% [markdown]
# ### . Rivermead Behavioural Memory Test (RBMT)
#
# General Memory Index RBMT

# %%
# Check missing values per group 
rbmt_ks = df[df["groep"] == 0]["RBMT"]
rbmt_hc = df[df["groep"] == 1]["RBMT"]

print("KS missing values: ", rbmt_ks.replace(missing_codes, np.nan).isna().sum())
print("KS values: ", rbmt_ks.unique())
print("HC missing values: ", rbmt_hc.replace(missing_codes, np.nan).isna().sum())
print("HC values: ", rbmt_hc.unique())
# Out:
# KS missing values:  6
# KS values:  [55. nan 58. 54. 53. 59. 56. 60. 57. 52. 78.]
# HC missing values:  20
# HC values:  [nan]

# %%
var = "RBMT"
data = df[var].replace(missing_codes, np.nan).dropna()
sns.histplot(data, kde=True)
plt.title(f"{var}")
plt.ylabel("Count")    
plt.show()

# %% [markdown]
# ### . Stroop Color-Word Test (SCWT)

# %% [markdown]
# - Stroop_k1 : Stroop time (sec) card 1
# - Stroop_k2 : Stroop time (sec) card 2
# - Stroop_k3 : Stroop time (sec) card 3
# - IF_Stroop : Raw interference score Stroop test
# - Tscore_IF_Stroop : T-score interferentie Strooptest
# - percent_IF_Stroop : Percentiel score interferentie Strooptest

# %%
df[['ID',"leeftijd", "opleiding", "Stroop_k1","Stroop_k2","Stroop_k3","IF_Stroop","Tscore_IF_Stroop","percent_IF_Stroop"]]
# Out:
#       ID  leeftijd  opleiding  Stroop_k1  Stroop_k2  Stroop_k3  IF_Stroop  \
# 0    1.0      58.0        6.0       54.0       69.0       96.0      109.0
# 1    2.0      65.0        3.0      104.0      132.0      350.0        NaN
# 2    3.0      54.0        5.0       46.0      100.0      134.0      147.0
# 3    4.0      58.0        5.0       60.0       79.0      110.0      125.0
# 4    5.0      53.0        3.0       68.0       80.0      154.0      132.0
# 5    6.0      64.0        2.0       60.0       77.0      113.0      123.0
# 6    7.0      67.0        4.0       75.0       79.0      193.0      137.0
# 7    8.0      52.0        NaN       65.0       63.0      122.0        NaN
# 8    9.0      44.0        3.0       42.0       49.0       85.0       84.0
# 9   10.0      58.0        NaN       56.0       65.0      103.0      117.0
# 10  11.0      54.0        5.0       49.0       61.0       85.0      100.0
# 11  12.0      57.0        4.0       67.0       72.0      121.0      119.0
# 12  13.0      63.0        5.0       58.0       68.0      121.0      114.0
# 13  14.0      64.0        5.0       45.0       49.0       69.0       87.0
# 14  15.0      67.0        6.0       50.0       56.0       99.0       96.0
# 15  16.0      49.0        5.0       43.0       56.0       66.0       94.0
# 16  17.0      51.0        6.0       44.0       59.0       75.0       94.0
# 17  18.0      51.0        6.0       46.0       68.0      126.0      105.0
# 18  19.0      59.0        5.0       45.0       65.0      117.0      108.0
# 19  20.0      53.0        6.0       38.0       46.0       75.0       77.0
# 20  21.0      57.0        5.0       85.0       78.0      131.0      124.0
# 21  22.0      62.0        2.0      120.0      140.0      264.0      234.0
# 22  23.0      75.0        2.0       95.0      116.0      194.0      232.0
# 23  24.0      59.0        4.0       62.0       72.0      190.0        NaN
# 24  25.0      60.0        5.0       47.0       68.0      108.0      112.0
# 25  26.0      67.0        5.0       54.0       70.0      104.0      120.0
# 26  27.0      43.0        6.0       38.0       44.0       73.0       72.0
# 27  28.0      55.0        5.0       64.0       71.0       96.0      113.0
# 28  29.0      67.0        6.0       49.0       61.0       92.0      104.0
# 29  30.0      65.0        6.0       52.0       64.0       94.0      107.0
# 30  31.0      65.0        5.0       49.0       73.0       86.0      123.0
# 31  32.0      67.0        5.0       48.0       61.0      113.0      104.0
# 32  33.0      67.0        5.0       39.0       43.0       81.0       78.0
# 33  34.0      51.0        5.0       49.0       56.0       83.0       92.0
# 34  35.0      56.0        5.0       45.0       55.0      100.0       93.0
# 35  36.0      54.0        3.0        NaN        NaN        NaN        NaN
# 36  37.0      64.0        5.0       47.0       72.0      101.0      120.0
# 37  38.0      66.0        NaN       55.0       88.0      260.0        NaN
# 38  39.0      54.0        6.0       57.0       77.0      124.0      117.0
# 39  40.0      58.0        5.0        NaN        NaN        NaN        NaN
#
#     Tscore_IF_Stroop  percent_IF_Stroop
# 0               57.0               76.0
# 1                NaN                NaN
# 2               53.0               62.0
# 3               56.0               73.0
# 4               44.0               27.0
# 5               54.0               66.0
# 6               39.0               14.0
# 7                NaN                NaN
# 8               49.0               46.0
# 9               56.0               73.0
# 10              60.0               84.0
# 11              49.0               46.0
# 12              47.0               38.0
# 13              66.0               95.0
# 14              49.0               46.0
# 15              74.0               99.0
# 16              65.0               93.0
# 17              41.0               18.0
# 18              46.0               34.0
# 19              52.0               58.0
# 20              47.0               38.0
# 21              47.0               38.0
# 22              55.0               69.0
# 23               NaN                NaN
# 24              52.0               58.0
# 25              57.0               76.0
# 26              49.0               46.0
# 27              59.0               82.0
# 28              57.0               76.0
# 29              57.0               76.0
# 30              69.0               97.0
# 31              46.0               34.0
# 32              48.0               42.0
# 33              57.0               76.0
# 34              46.0               34.0
# 35               NaN                NaN
# 36              59.0               82.0
# 37               NaN                NaN
# 38              47.0               38.0
# 39               NaN                NaN

# %%
# Check missing values per group 
variables = ["Stroop_k1","Stroop_k2","Stroop_k3","IF_Stroop","Tscore_IF_Stroop","percent_IF_Stroop"]
results = []

for var in variables:
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan)
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan)
    results.append({"Variable": var,"KS": ks.isna().sum(),"HC": hc.isna().sum(),\
                    "KS_unique_values": ks.unique(), "HC_unique_values": hc.unique()})

missing_table = pd.DataFrame(results).set_index("Variable")
display(missing_table)
# Out:
#                    KS  HC                                   KS_unique_values  \
# Variable
# Stroop_k1           1   1  [54.0, 104.0, 46.0, 60.0, 68.0, 75.0, 65.0, 42...
# Stroop_k2           1   1  [69.0, 132.0, 100.0, 79.0, 80.0, 77.0, 63.0, 4...
# Stroop_k3           1   1  [96.0, 350.0, 134.0, 110.0, 154.0, 113.0, 193....
# IF_Stroop           5   1  [109.0, nan, 147.0, 125.0, 132.0, 123.0, 137.0...
# Tscore_IF_Stroop    5   1  [57.0, nan, 53.0, 56.0, 44.0, 54.0, 39.0, 49.0...
# percent_IF_Stroop   5   1  [76.0, nan, 62.0, 73.0, 27.0, 66.0, 14.0, 46.0...
#
#                                                     HC_unique_values
# Variable
# Stroop_k1          [45.0, 50.0, 43.0, 44.0, 46.0, 38.0, 47.0, 54....
# Stroop_k2          [49.0, 56.0, 59.0, 68.0, 65.0, 46.0, 70.0, 44....
# Stroop_k3          [69.0, 99.0, 66.0, 75.0, 126.0, 117.0, 108.0, ...
# IF_Stroop          [87.0, 96.0, 94.0, 105.0, 108.0, 77.0, 112.0, ...
# Tscore_IF_Stroop   [66.0, 49.0, 74.0, 65.0, 41.0, 46.0, 52.0, 57....
# percent_IF_Stroop  [95.0, 46.0, 99.0, 93.0, 18.0, 34.0, 58.0, 76....

# %%
fig, axes = plt.subplots(nrows=len(variables),ncols=2,figsize=(12, 3 * len(variables)),sharex=False)

for i, var in enumerate(variables):
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan).dropna()
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan).dropna()

    # KS distribution
    sns.histplot(ks, kde=True, ax=axes[i, 0])
    axes[i, 0].set_title(f"{var} – KS")
    axes[i, 0].set_ylabel("Count")

    # HC distribution
    sns.histplot(hc, kde=True, ax=axes[i, 1])
    axes[i, 1].set_title(f"{var} – HC")

plt.tight_layout()
plt.show()

# %%
# T-test
ks = df[df["groep"] == 0]["IF_Stroop"].replace(missing_codes, np.nan).dropna()
hc = df[df["groep"] == 1]["IF_Stroop"].replace(missing_codes, np.nan).dropna()

print(f"KS: n={len(ks)}, mean={ks.mean():.2f}, SD={ks.std():.2f}")
print(f"HC: n={len(hc)}, mean={hc.mean():.2f}, SD={hc.std():.2f}")

t_stat, p_value = ttest_ind(ks.dropna(), hc.dropna(), equal_var=False)  # Welch's t-test
print(f"t = {t_stat:.3f}, p = {p_value:.4f}")
# Out:
# KS: n=15, mean=134.27, SD=42.74
# HC: n=19, mean=99.95, SD=14.87
# t = 2.971, p = 0.0087

# %% [markdown]
# ### . Dutch California Verbal Learning Test (NVL)
#
# Deviatie-IQ NLV, overall capacity to acquire and retrain verbal information

# %%
# Check missing values per group 
nlv_ks = df[df["groep"] == 0]["NLV"]
nlv_hc = df[df["groep"] == 1]["NLV"]

print("KS missing values: ", nlv_ks.replace(missing_codes, np.nan).isna().sum())
print("KS values: ", nlv_ks.unique())
print("HC missing values: ", nlv_hc.replace(missing_codes, np.nan).isna().sum())
print("HC values: ", nlv_hc.unique())
# Out:
# KS missing values:  5
# KS values:  [117.  nan 106.  95.  75. 107.  78.  92.  76.  90.  70.  98.  84.  67.]
# HC missing values:  0
# HC values:  [ 87. 104.  84. 120. 116. 102.  94. 123. 100.  92. 115. 113. 109. 129.
#  107.  86.  93. 103.]

# %%
variables = ["NLV"]
fig, axes = plt.subplots(nrows=len(variables),ncols=2,figsize=(12, 3 * len(variables)),sharex=False)

for i, var in enumerate(variables):
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan).dropna()
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan).dropna()

    # KS distribution
    sns.histplot(ks, kde=True, ax=axes[0])
    axes[0].set_title(f"{var} – KS")
    axes[0].set_ylabel("Count")

    # HC distribution
    sns.histplot(hc, kde=True, ax=axes[1])
    axes[1].set_title(f"{var} – HC")

plt.tight_layout()
plt.show()

# %%
variables = ["NLV"]
fig, axes = plt.subplots(nrows=len(variables),ncols=2,figsize=(12, 3 * len(variables)),sharex=True,squeeze=False)

for i, var in enumerate(variables):
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan).dropna()
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan).dropna()

    min_val = min(ks.min(), hc.min())
    max_val = max(ks.max(), hc.max())

    bins = np.arange(np.floor(min_val / 5) * 5,np.ceil(max_val / 5) * 5 + 5,5)

    # KS
    sns.histplot(ks, bins=bins, kde=True, ax=axes[i, 0])
    axes[i, 0].set_title(f"{var} – KS")
    axes[i, 0].set_ylabel("Count")
    axes[i, 0].set_xticks(bins)

    # HC
    sns.histplot(hc, bins=bins, kde=True, ax=axes[i, 1])
    axes[i, 1].set_title(f"{var} – HC")
    axes[i, 1].set_xticks(bins)

plt.tight_layout()
plt.show()

# %%
# T-test
print(f"KS: n={len(ks)}, mean={ks.mean():.2f}, SD={ks.std():.2f}")
print(f"HC: n={len(hc)}, mean={hc.mean():.2f}, SD={hc.std():.2f}")

t_stat, p_value = ttest_ind(ks.dropna(), hc.dropna(), equal_var=False)  # Welch's t-test
print(f"t = {t_stat:.3f}, p = {p_value:.4f}")
# Out:
# KS: n=15, mean=89.27, SD=14.38
# HC: n=20, mean=102.55, SD=13.68
# t = -2.760, p = 0.0098

# %% [markdown]
# ### . Wechsler Adult Intelligence Scale (WAIS-IV)

# %%
# Check missing values per group 
variables = ["TIQ_WAIS","VBI_WAIS","PRI_WAIS","WG_WAIS"]
results = []

for var in variables:
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan)
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan)
    results.append({"Variable": var,"KS": ks.isna().sum(),"HC": hc.isna().sum(),\
                    "KS_unique_values": ks.unique(), "HC_unique_values": hc.unique()})

missing_table = pd.DataFrame(results).set_index("Variable")
display(missing_table)
# Out:
#           KS  HC                                   KS_unique_values  \
# Variable
# TIQ_WAIS   7  20  [95.0, nan, 74.0, 72.0, 81.0, 64.0, 79.0, 88.0...
# VBI_WAIS   6  20  [116.0, nan, 74.0, 83.0, 100.0, 70.0, 86.0, 91...
# PRI_WAIS   6  20  [85.0, nan, 68.0, 77.0, 69.0, 72.0, 83.0, 94.0...
# WG_WAIS    6  20  [112.0, nan, 100.0, 83.0, 105.0, 74.0, 103.0, ...
#
#          HC_unique_values
# Variable
# TIQ_WAIS            [nan]
# VBI_WAIS            [nan]
# PRI_WAIS            [nan]
# WG_WAIS             [nan]

# %%
fig, axes = plt.subplots(nrows=len(variables),ncols=1,figsize=(5, 3 * len(variables)),sharex=False)

for i, var in enumerate(variables):
    data = df[var].replace(missing_codes, np.nan).dropna()
    sns.histplot(data, kde=True, ax=axes[i])
    axes[i].set_title(f"{var}")
    axes[i].set_ylabel("Count")
    
plt.tight_layout()
plt.show()

# %%
variables = ["TIQ_WAIS"]

# Force axes to always be an array, even if nrows=1
fig, axes = plt.subplots(nrows=len(variables),ncols=1,figsize=(5, 3 * len(variables)),sharex=False,squeeze=False)

for i, var in enumerate(variables):
    data = df[var].replace(missing_codes, np.nan).dropna()

    # Define bins every 5
    min_val = data.min()
    max_val = data.max()
    bins = np.arange(np.floor(min_val / 5) * 5,np.ceil(max_val / 5) * 5 + 5,5)

    # Plot
    sns.histplot(data, bins=bins, kde=True, ax=axes[i, 0])
    axes[i, 0].set_title(f"{var}")
    axes[i, 0].set_ylabel("Count")
    axes[i, 0].set_xticks(bins)  # align x-ticks with bin edges

plt.tight_layout()
plt.show()

# %% [markdown]
# ### . Location Learning Test (LLT)

# %% [markdown]
# - PF_LLT: Total placement errors location learning test
# - percent_PF_LLT : Percentile score total PF location learning test
# - leerind_LLT : Learning index location learning test
# - percent_leerind_LLT : Percentile score learning index location learning test

# %%
# Check missing values per group 
variables = ["PF_LLT","percent_PF_LLT","leerind_LLT","percent_leerind_LLT"]
results = []

for var in variables:
    ks = df[df["groep"] == 0][var].replace(missing_codes, np.nan)
    hc = df[df["groep"] == 1][var].replace(missing_codes, np.nan)
    results.append({"Variable": var,"KS": ks.isna().sum(),"HC": hc.isna().sum(),\
                    "KS_unique_values": ks.unique(), "HC_unique_values": hc.unique()})

missing_table = pd.DataFrame(results).set_index("Variable")
display(missing_table)
# Out:
#                      KS  HC  \
# Variable
# PF_LLT                7  20
# percent_PF_LLT        7  20
# leerind_LLT           7  20
# percent_leerind_LLT   7  20
#
#                                                       KS_unique_values  \
# Variable
# PF_LLT               [125.0, nan, 60.0, 119.0, 83.0, 70.0, 67.0, 98...
# percent_PF_LLT                         [1.0, nan, 4.0, 13.0, 2.0, 5.0]
# leerind_LLT          [0.05, nan, 0.105, 0.07, 0.12, 0.14, 0.195, 0....
# percent_leerind_LLT              [1.0, nan, 4.0, 18.0, 2.0, 13.0, 8.0]
#
#                     HC_unique_values
# Variable
# PF_LLT                         [nan]
# percent_PF_LLT                 [nan]
# leerind_LLT                    [nan]
# percent_leerind_LLT            [nan]

# %%
fig, axes = plt.subplots(nrows=len(variables),ncols=1,figsize=(5, 3 * len(variables)),sharex=False)

for i, var in enumerate(variables):
    data = df[var].replace(missing_codes, np.nan).dropna()
    sns.histplot(data, kde=True, ax=axes[i])
    axes[i].set_title(f"{var}")
    axes[i].set_ylabel("Count")
    
plt.tight_layout()
plt.show()
